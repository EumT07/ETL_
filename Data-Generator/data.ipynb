# %%
from data import FakeDataGenerator

# %%
# generator = FakeDataGenerator()
generator = FakeDataGenerator(max_size=500000, customer_size=8000, products_size=500, orders_size=70000)
dataset = generator.generate()

# %% [markdown]
# Check Data

# %%
dataset.count()
# Out:
# _id                  500000
# cst_id               500000
# cst_first_name       500000
# cst_last_name        500000
# cst_birth_day        500000
# cst_email            500000
# cst_address          500000
# cst_gender           500000
# cst_country          500000
# cst_reviews          500000
# cst_ads_source       500000
# pro_id               500000
# pro_name             500000
# pro_brand            500000
# pro_category         500000
# pro_sub_category     500000
# pro_unit_price       319151
# pro_quantity         344106
# pro_total            500000
# or_id                500000
# or_status            500000
# or_payment_method    500000
# or_purchase_date     500000
# or_shipping_date     500000
# or_delivery_date     500000
# dtype: int64
