# %%
from data import FakeDataGenerator

# %%
generator = FakeDataGenerator()
dataset = generator.generate(max_size=4000)

# %% [markdown]
# Check Data

# %%
dataset.count()
# Out:
# _id                  4000
# cst_id               4000
# cst_first_name       4000
# cst_last_name        4000
# cst_birth_day        4000
# cst_email            4000
# cst_address          4000
# cst_gender           4000
# cst_country          4000
# cst_reviews          4000
# pro_id               4000
# pro_name             4000
# pro_brand            4000
# pro_category         4000
# pro_sub_category     4000
# pro_unit_price       2658
# pro_quantity         2686
# pro_total            4000
# or_id                4000
# or_status            4000
# or_payment_method    4000
# or_purchase_date     4000
# or_shipping_date     4000
# or_delivery_date     4000
# dtype: int64
